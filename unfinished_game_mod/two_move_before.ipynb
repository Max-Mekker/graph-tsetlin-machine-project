# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib import ticker
import seaborn as sns
import numpy as np
from time import time
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,recall_score, precision_score, f1_score, confusion_matrix
from GraphTsetlinMachine.tm import MultiClassGraphTsetlinMachine
from GraphTsetlinMachine.graphs import Graphs   

# For when not using command line arguments:
import argparse
parser = argparse.ArgumentParser()
parser.add_argument('-f') # Dummy argument

#plt.switch_backend('Agg') # Disable plots if backend not interactive

board_count = 0
board_size = 0
board_type = ""
boards = []
labels = []
label_names = ["X_win", "O_win"]

# Load dataset
with open("hex_complete_5x5_4000_mostly_filled.txt") as f:
    
    board_count, board_size, empty = [int(x) for x in f.readline().split(' ')]
    
    if "barely" in f.name:
        board_type = f"Barely filled (>={empty} empty cells)"
    elif "mostly" in f.name:
        board_type = f"Mostly filled (<={empty} empty cells)"
    else: board_type = f"Randomly filled ({empty} empty cells)"

    boards = np.empty([board_count, board_size, board_size], dtype=str)
    current_board = 0
    row = 0
    
    X_count = 0
    O_count = 0
    
    for line in f:
        if line == '\n':
            continue
        if row < board_size:
            for column, char in enumerate(line.rstrip()):
                boards[current_board][row][column] = char
            row += 1
        else:
            row = 0
            
            # Count wins to see if dataset is balanced
            if int(line.rstrip()) == 0:
                X_count += 1
            else:
                O_count += 1
            
            labels.append(int(line.rstrip()))
            current_board += 1

# %%
def generate_two_moves_before(boards, labels):
    two_moves_boards = []
    two_moves_labels = []
    for game, label in zip(boards, labels):
        total_moves = np.sum(game != '*')  
        if total_moves > 2:  
            intermediate_state = game.copy()
            empty_count = 2  
            for i in range(len(game)):
                for j in range(len(game[i])):
                    if intermediate_state[i, j] != '*' and empty_count > 0:
                        intermediate_state[i, j] = '*'  
                        empty_count -= 1
            two_moves_boards.append(intermediate_state)
            two_moves_labels.append(label)

    return np.array(two_moves_boards), np.array(two_moves_labels)

# %%
def plot_metrics(accuracy_train, precision_train, recall_train, f1_train, accuracy_test, precision_test, recall_test, f1_test, epochs, board_size, board_type):
    # Plot accuracy, precision, recall and f1-score for training and testing
    
    dataset_types = ["Train", "Test"]
    
    x_values = np.arange(1, epochs+1, 1)
    fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharey='all', constrained_layout=True)
    fig.suptitle(f'GTM Metrics for Training and Testing, {board_size}x{board_size}, Two Moves Before End,\n {epochs} Epochs, {board_type}', fontweight='bold')
    
    blue = [(0.6, 0.76, 0.98), (0, 0.21, 0.46)] 
    orange = [(255/255, 197/255, 165/255), (200/255, 71/255, 0/255)]
    red = [(255/255, 176/255, 165/255), (180/255, 21/255, 0/255)]
    purple = [(219/255, 165/255, 255/255), (119/255, 0/255, 200/255)]
    blue_cm = mpl.colors.LinearSegmentedColormap.from_list('custom_blue', blue, N=10)
    orange_cm = mpl.colors.LinearSegmentedColormap.from_list('custom_orange', orange, N=10)
    red_cm = mpl.colors.LinearSegmentedColormap.from_list('custom_red', red, N=10)
    purple_cm = mpl.colors.LinearSegmentedColormap.from_list('custom_purple', purple, N=10)

    colormaps = [blue_cm, orange_cm, red_cm, purple_cm]

    accuracy_colors = colormaps[0](np.linspace(0, 1, len(dataset_types)))
    precision_colors = colormaps[1](np.linspace(0, 1, len(dataset_types)))
    recall_colors = colormaps[2](np.linspace(0, 1, len(dataset_types)))
    f1_colors = colormaps[3](np.linspace(0, 1, len(dataset_types)))

    ax1.set_title('Accuracy')
    ax2.set_title('Precision')
    ax3.set_title('Recall')
    ax4.set_title('F1')
    
    for index, ax in enumerate (fig.get_axes()):
        ax.set(xlabel='$\it{Epoch}$', ylabel='$\it{Score}$')
        ax.xaxis.set_major_locator(mpl.ticker.MaxNLocator(integer=True))
        ax.label_outer()
        ax.grid()
        
        bounds = [0, 1, 2]
        norm = mpl.colors.BoundaryNorm(bounds, colormaps[index].N)
        scalar_mappable = plt.cm.ScalarMappable(cmap=colormaps[index], norm=norm)
        
        clb = plt.colorbar(scalar_mappable, ax=ax)
        clb.ax.set_xlabel('Dataset', fontsize=7, loc='left')
        clb.ax.set_yticks([0.5, 1.5])
        clb.ax.set_yticklabels(dataset_types, fontsize=7)

    ax1.plot(x_values, accuracy_train, color=accuracy_colors[0])
    ax2.plot(x_values, precision_train, color=precision_colors[0])
    ax3.plot(x_values, recall_train, color=recall_colors[0])
    ax4.plot(x_values, f1_train, color=f1_colors[0])
    
    ax1.plot(x_values, accuracy_test, color=accuracy_colors[1])
    ax2.plot(x_values, precision_test, color=precision_colors[1])
    ax3.plot(x_values, recall_test, color=recall_colors[1])
    ax4.plot(x_values, f1_test, color=f1_colors[1])
    
    ax.set_ylim(top=1.001)
    
    fig.savefig(f"metrics_{board_size}x{board_size}_Two_moves{epochs}_epochs_{board_type.split(' ')[0]}.png", dpi=1200)
    fig.show()


def main():
    # Track runtime
    start_time = time()
    
    # Parameters:
    epochs = 30
    number_of_clauses = 2000
    T = 3500
    s = 2.1
    depth = 3
    hypervector_size = 512
    hypervector_bits = 1
    message_size = 8192
    message_bits = 1
    max_included_literals = 32
    
    # Print info about dataset
    print(f"Dataset:\n"
      f"Board size:  {board_size}x{board_size}\n"
      f"Board count: {board_count}\n"
      f"Board type:  {board_type}\n"
      f"X wins:      {X_count}\n"
      f"O wins:      {O_count}\n"
      f"")
    
    print("X: Vertical   - win=0\n"
          "O: Horizontal - win=1\n")
    
    print("Game 1 & 2:")              
    print(boards[:2]) 
    print()
    print("Game 1 & 2 Results:")
    print(labels[:2])
    print("\n")
    
    # Split dataset
    #X_train_2_before, X_test_2_before, Y_train_2_before, Y_test_2_before = train_test_split(boards, np.array(labels, dtype=np.uint32), test_size=0.20, random_state=42)
    boards_2_before, labels_2_before = generate_two_moves_before(boards, labels)
    X_train_2_before, X_test_2_before, Y_train_2_before, Y_test_2_before = train_test_split(boards_2_before, labels_2_before, test_size=0.20, random_state=42)




    #************************************** Initialize graphs for training data ***************************************
    graphs_train = Graphs(
        X_train_2_before.shape[0],
        symbols=['X', 'O', '*', 'Xw', 'Ow', 'Xc', 'Xs', 'Oc', 'Os'],
        hypervector_size=hypervector_size, # Number of features
        hypervector_bits=hypervector_bits
    )
    
    for graph_id in range(X_train_2_before.shape[0]):
        graphs_train.set_number_of_graph_nodes(graph_id, board_size*board_size)
    
    # Add nodes
    graphs_train.prepare_node_configuration()
    
    for graph_id in range( X_train_2_before.shape[0]):
        for i in range(board_size):
            for j in range(board_size):
                if j == 0 or j == board_size-1 or i == 0 or i == board_size-1:
                    # Along borders of board
                    if (i == 0 and j == 0) or (i == board_size-1 and j == board_size-1):
                        number_of_outgoing_edges = 2 # Top left / bottom right
                        graphs_train.add_graph_node(graph_id, f"n{i}{j}", number_of_outgoing_edges)
                    elif (i == 0 and j == board_size-1) or (i == board_size-1 and j == 0):
                        number_of_outgoing_edges = 3 # Top right / bottom left
                        graphs_train.add_graph_node(graph_id, f"n{i}{j}", number_of_outgoing_edges)
                    else:
                        number_of_outgoing_edges = 4 # Between corners
                        graphs_train.add_graph_node(graph_id, f"n{i}{j}", number_of_outgoing_edges)
                else:
                    number_of_outgoing_edges = 6 # Middle
                    graphs_train.add_graph_node(graph_id, f"n{i}{j}", number_of_outgoing_edges)


    # Add edges
    graphs_train.prepare_edge_configuration()
    
    # Add node properties and class labels
    for graph_id in range(X_train_2_before.shape[0]):
        for i in range(board_size):
            for j in range(board_size):
                graphs_train.add_graph_node_property(graph_id, f"n{i}{j}",  X_train_2_before[graph_id][i][j])
                
                # Wall nodes top bottom
                if i == 0 or i == board_size-1:
                    graphs_train.add_graph_node_property(graph_id, f"n{i}{j}", 'Xw')
                    
                # Wall nodes left right
                if j == 0 or j == board_size-1:
                    graphs_train.add_graph_node_property(graph_id, f"n{i}{j}", 'Ow')
                    
                    
    for graph_id in range(X_train_2_before.shape[0]):
        for i in range(board_size):
            for j in range(board_size):
                # Specify edge between nodes as a "chain" if it connects two pieces of the same type
                chained = 0
                if j != board_size-1:
                    if  X_train_2_before[graph_id][i][j+1] ==  X_train_2_before[graph_id][i][j] != '*':
                        # Right neighbour of same type
                        graphs_train.add_graph_node_edge(graph_id, f"n{i}{j}", f"n{i}{j+1}", f"right_{ X_train_2_before[graph_id][i][j]}_chain")
                        chained = 1
                    else:
                        # Attempt to dynamically adjust number of node edges
                        # num = graphs_train.number_of_graph_node_edges[graphs_train.node_index[graph_id] + graphs_train.graph_node_id[graph_id][f'n{i}{j}']]
                        # graphs_train.number_of_graph_node_edges[graphs_train.node_index[graph_id] + graphs_train.graph_node_id[graph_id][f'n{i}{j}']] = num - 1
                        graphs_train.add_graph_node_edge(graph_id, f"n{i}{j}", f"n{i}{j+1}", "right") # Right
                
                if i != board_size-1:
                    if  X_train_2_before[graph_id][i+1][j] ==  X_train_2_before[graph_id][i][j] != '*':
                        graphs_train.add_graph_node_edge(graph_id, f"n{i}{j}", f"n{i+1}{j}", f"down_right_{ X_train_2_before[graph_id][i][j]}_chain")
                        chained = 1
                    else:
                        graphs_train.add_graph_node_edge(graph_id, f"n{i}{j}", f"n{i+1}{j}", "down_right") # Down-right
                    
                if j != 0 and i != board_size-1:
                    if  X_train_2_before[graph_id][i+1][j-1] ==  X_train_2_before[graph_id][i][j] != '*':
                        graphs_train.add_graph_node_edge(graph_id, f"n{i}{j}", f"n{i+1}{j-1}", f"down_left_{ X_train_2_before[graph_id][i][j]}_chain")
                        chained = 1
                    else:
                        graphs_train.add_graph_node_edge(graph_id, f"n{i}{j}", f"n{i+1}{j-1}", "down_left") # Down-left
                    
                if j != 0:
                    if  X_train_2_before[graph_id][i][j-1] ==  X_train_2_before[graph_id][i][j] != '*':
                        graphs_train.add_graph_node_edge(graph_id, f"n{i}{j}", f"n{i}{j-1}", f"left_{ X_train_2_before[graph_id][i][j]}_chain")
                        chained = 1
                    else:
                        graphs_train.add_graph_node_edge(graph_id, f"n{i}{j}", f"n{i}{j-1}", "left") # Left
                    
                if i != 0:
                    if  X_train_2_before[graph_id][i-1][j] ==  X_train_2_before[graph_id][i][j] != '*':
                        graphs_train.add_graph_node_edge(graph_id, f"n{i}{j}", f"n{i-1}{j}", f"up_left_{X_train_2_before[graph_id][i][j]}_chain")
                        chained = 1
                    else:
                        graphs_train.add_graph_node_edge(graph_id, f"n{i}{j}", f"n{i-1}{j}", "up_left") # Up-left
                
                if i != 0 and j != board_size-1:
                    if X_train_2_before[graph_id][i-1][j+1] == X_train_2_before[graph_id][i][j] != '*':
                        graphs_train.add_graph_node_edge(graph_id, f"n{i}{j}", f"n{i-1}{j+1}", f"up_right_{X_train_2_before[graph_id][i][j]}_chain")
                        chained = 1
                    else:
                        graphs_train.add_graph_node_edge(graph_id, f"n{i}{j}", f"n{i-1}{j+1}", "up_right") # Up-right
                        
                # Add property of either "chained" or "solo" to node as well
                if chained == 1:
                    graphs_train.add_graph_node_property(graph_id, f"n{i}{j}", f'{X_train_2_before[graph_id][i][j]}c')
                elif X_train_2_before[graph_id][i][j] != '*':
                    graphs_train.add_graph_node_property(graph_id, f"n{i}{j}", f'{X_train_2_before[graph_id][i][j]}s')
                    
    graphs_train.encode()
    
    
    #************************************** Initialize graphs for test data ***************************************
    graphs_test = Graphs(X_test_2_before.shape[0], init_with=graphs_train)
    
    for graph_id in range(X_test_2_before.shape[0]):
        graphs_test.set_number_of_graph_nodes(graph_id, board_size*board_size)
    
    # Add nodes
    graphs_test.prepare_node_configuration()
    
    for graph_id in range(X_test_2_before.shape[0]):
        for i in range(board_size):
            for j in range(board_size):
                if j == 0 or j == board_size-1 or i == 0 or i == board_size-1:
                    # Along borders of board
                    if (i == 0 and j == 0) or (i == board_size-1 and j == board_size-1):
                        number_of_outgoing_edges = 2 # Top left / bottom right
                        graphs_test.add_graph_node(graph_id, f"n{i}{j}", number_of_outgoing_edges)
                    elif (i == 0 and j == board_size-1) or (i == board_size-1 and j == 0):
                        number_of_outgoing_edges = 3 # Top right / bottom left
                        graphs_test.add_graph_node(graph_id, f"n{i}{j}", number_of_outgoing_edges)
                    else:
                        number_of_outgoing_edges = 4 # Between corners
                        graphs_test.add_graph_node(graph_id, f"n{i}{j}", number_of_outgoing_edges)
                else:
                    number_of_outgoing_edges = 6 # Middle
                    graphs_test.add_graph_node(graph_id, f"n{i}{j}", number_of_outgoing_edges)


    # Add edges
    graphs_test.prepare_edge_configuration()
    
    # Add node properties and class labels
    for graph_id in range(X_test_2_before.shape[0]):
        for i in range(board_size):
            for j in range(board_size):
                graphs_test.add_graph_node_property(graph_id, f"n{i}{j}", X_test_2_before[graph_id][i][j])
                
                # Wall nodes top bottom
                if i == 0 or i == board_size-1:
                    graphs_test.add_graph_node_property(graph_id, f"n{i}{j}", 'Xw')
                    
                # Wall nodes left right
                if j == 0 or j == board_size-1:
                    graphs_test.add_graph_node_property(graph_id, f"n{i}{j}", 'Ow')
                    
                    
    for graph_id in range(X_test_2_before.shape[0]):
        for i in range(board_size):
            for j in range(board_size):
                # Specify edge between nodes as a "chain" if it connects two pieces of the same type
                chained = 0
                if j != board_size-1:
                    if X_test_2_before[graph_id][i][j+1] == X_test_2_before[graph_id][i][j] != '*':
                        # Right neighbour of same type
                        graphs_test.add_graph_node_edge(graph_id, f"n{i}{j}", f"n{i}{j+1}", f"right_{X_test_2_before[graph_id][i][j]}_chain")
                        chained = 1
                    else:
                        graphs_test.add_graph_node_edge(graph_id, f"n{i}{j}", f"n{i}{j+1}", "right") # Right
                
                if i != board_size-1:
                    if X_test_2_before[graph_id][i+1][j] == X_test_2_before[graph_id][i][j] != '*':
                        graphs_test.add_graph_node_edge(graph_id, f"n{i}{j}", f"n{i+1}{j}", f"down_right_{X_test_2_before[graph_id][i][j]}_chain")
                        chained = 1
                    else:
                        graphs_test.add_graph_node_edge(graph_id, f"n{i}{j}", f"n{i+1}{j}", "down_right") # Down-right
                    
                if j != 0 and i != board_size-1:
                    if X_test_2_before[graph_id][i+1][j-1] == X_test_2_before[graph_id][i][j] != '*':
                        graphs_test.add_graph_node_edge(graph_id, f"n{i}{j}", f"n{i+1}{j-1}", f"down_left_{X_test_2_before[graph_id][i][j]}_chain")
                        chained = 1
                    else:
                        graphs_test.add_graph_node_edge(graph_id, f"n{i}{j}", f"n{i+1}{j-1}", "down_left") # Down-left
                    
                if j != 0:
                    if X_test_2_before[graph_id][i][j-1] == X_test_2_before[graph_id][i][j] != '*':
                        graphs_test.add_graph_node_edge(graph_id, f"n{i}{j}", f"n{i}{j-1}", f"left_{X_test_2_before[graph_id][i][j]}_chain")
                        chained = 1
                    else:
                        graphs_test.add_graph_node_edge(graph_id, f"n{i}{j}", f"n{i}{j-1}", "left") # Left
                    
                if i != 0:
                    if X_test_2_before[graph_id][i-1][j] == X_test_2_before[graph_id][i][j] != '*':
                        graphs_test.add_graph_node_edge(graph_id, f"n{i}{j}", f"n{i-1}{j}", f"up_left_{X_test_2_before[graph_id][i][j]}_chain")
                        chained = 1
                    else:
                        graphs_test.add_graph_node_edge(graph_id, f"n{i}{j}", f"n{i-1}{j}", "up_left") # Up-left
                
                if i != 0 and j != board_size-1:
                    if X_test_2_before[graph_id][i-1][j+1] == X_test_2_before[graph_id][i][j] != '*':
                        graphs_test.add_graph_node_edge(graph_id, f"n{i}{j}", f"n{i-1}{j+1}", f"up_right_{X_test_2_before[graph_id][i][j]}_chain")
                        chained = 1
                    else:
                        graphs_test.add_graph_node_edge(graph_id, f"n{i}{j}", f"n{i-1}{j+1}", "up_right") # Up-right
                        
                # Add property of either "chained" or "solo" to node as well
                if chained == 1:
                    graphs_test.add_graph_node_property(graph_id, f"n{i}{j}", f'{X_test_2_before[graph_id][i][j]}c')
                elif X_test_2_before[graph_id][i][j] != '*':
                    graphs_test.add_graph_node_property(graph_id, f"n{i}{j}", f'{X_test_2_before[graph_id][i][j]}s')
            
    graphs_test.encode()
    
    
    #************************************** Initialize Graph Tsetlin Machine ***************************************
    tm = MultiClassGraphTsetlinMachine(
        number_of_clauses = number_of_clauses,
        T = T,
        s = s,
        depth = depth,
        message_size = message_size,
        message_bits = message_bits,
        max_included_literals = max_included_literals,
        grid=(16*13,1,1)
    )
    
    
    # For plotting performance metrics
    acc_test_seq = []
    acc_train_seq = []
    
    precision_train_seq = []
    precision_test_seq = []
    
    recall_train_seq = []
    recall_test_seq = []
    
    f1_score_train_seq = []
    f1_score_test_seq = []
    
    cm = []
    
    
    # For each epoch:
    for i in range(epochs):
        
        start_training = time()
        tm.fit(graphs_train, Y_train_2_before, epochs = 1, incremental=True)
        stop_training = time()
        
        start_testing = time()
        result_test = tm.predict(graphs_test)
        stop_testing = time()
        
        result_train = tm.predict(graphs_train)
    
       
        # Performance metrics
        acc_train = accuracy_score(Y_train_2_before, result_train)
        acc_test = accuracy_score(Y_test_2_before, result_test)
        acc_train_seq.append(acc_train)
        acc_test_seq.append(acc_test)
        
        precision_train = precision_score(Y_train_2_before, result_train)
        precision_test = precision_score(Y_test_2_before, result_test)
        precision_train_seq.append(precision_train)
        precision_test_seq.append(precision_test)
        
        recall_train = recall_score(Y_train_2_before, result_train)
        recall_test = recall_score(Y_test_2_before, result_test)
        recall_train_seq.append(recall_train)
        recall_test_seq.append(recall_test)
        
        f1_score_train = f1_score(Y_train_2_before, result_train)
        f1_score_test = f1_score(Y_test_2_before, result_test)
        f1_score_train_seq.append(f1_score_train)
        f1_score_test_seq.append(f1_score_test)
        
        if i == epochs-1:
            cm = confusion_matrix(Y_test_2_before, result_test)

        
        print(f"\nEPOCH {i+1: <24}   Total Runtime: {time()-start_time:8.2f}s\n"
              f"Training Accuracy:  {100*acc_train:7.2f}%  |  Test Accuracy:  {100*acc_test:7.2f}%  \n"
              f"Training Precision: {100*precision_train:7.2f}%  |  Test Precision: {100*precision_test:7.2f}%  \n"
              f"Training Recall:    {100*recall_train:7.2f}%  |  Test Recall:    {100*recall_test:7.2f}%  \n"
              f"Training F1:        {100*f1_score_train:7.2f}%  |  Test F1:        {100*f1_score_test:7.2f}%  \n"
              f"Training Time:      {stop_training-start_training:7.4f}s  |  Test Time:      {stop_testing-start_testing:7.4f}s")
        
        
    # Plot cm
    plt.figure()
    sns.heatmap(cm, annot=True, fmt='d', xticklabels=label_names, yticklabels=label_names)
    plt.title(f"Confusion Matrix for Test Predictions of {board_size}x{board_size} Two Moves Before End,\n {epochs} Epochs, {board_type}", fontweight='bold')
    plt.xlabel("Predicted Result", fontweight='bold')
    plt.ylabel("Actual Result", fontweight='bold')
    plt.savefig(f"cm_{board_size}x{board_size}_Two_moves{epochs}_epochs_{board_type.split(' ')[0]}.png", dpi=1200)
    plt.close()
 
    # Plot metrics
    plt.style.use('default')
    plot_metrics(acc_train_seq, precision_train_seq, recall_train_seq, f1_score_train_seq, acc_test_seq, precision_test_seq, recall_test_seq, f1_score_test_seq, epochs, board_size, board_type)
        
        
    # Print misc. info
    weights = tm.get_state()[1].reshape(2, -1)
    print()
    for i in range(tm.number_of_clauses):
        if i < 10:
            print("Clause #%d W: (%d %d)" % (i, weights[0, i], weights[1, i]), end=' ')
            l = []
            for k in range(hypervector_size * 2):
                if tm.ta_action(0, i, k):
                    if k < hypervector_size:
                        l.append("x%d" % (k))
                    else:
                        l.append("NOT x%d" % (k - hypervector_size))
                    
            print(" AND ".join(l))
            print(f"Number of literals: {len(l)}")
        
    print(graphs_train.hypervectors)
    #print(tm.hypervectors)
    print(graphs_test.edge_type_id)


if __name__ == "__main__":
    main()
# Out:
# Dataset:
# Board size:  5x5
# Board count: 4000
# Board type:  Mostly filled (<=2 empty cells)
# X wins:      2003
# O wins:      1997
#
# X: Vertical   - win=0
# O: Horizontal - win=1
#
# Game 1 & 2:
# [[['X' 'X' 'X' 'O' 'X']
#   ['X' 'O' 'X' 'O' 'O']
#   ['O' 'O' 'X' 'X' 'O']
#   ['O' 'X' 'O' 'X' 'O']
#   ['O' 'X' 'X' 'O' 'X']]
#
#  [['X' 'X' 'O' 'X' 'O']
#   ['X' 'X' 'O' 'O' 'X']
#   ['O' 'X' 'O' 'X' 'X']
#   ['O' 'X' '*' 'O' 'X']
#   ['*' 'X' 'O' 'O' 'O']]]
#
# Game 1 & 2 Results:
# [0, 0]
#
#
# Initialization of sparse structure.
#
# EPOCH 1                          Total Runtime:    65.41s
# Training Accuracy:    89.06%  |  Test Accuracy:    89.00%
# Training Precision:   92.49%  |  Test Precision:   90.99%
# Training Recall:      85.29%  |  Test Recall:      85.22%
# Training F1:          88.75%  |  Test F1:          88.01%
# Training Time:      36.5427s  |  Test Time:       4.4765s
#
# EPOCH 2                          Total Runtime:   119.65s
# Training Accuracy:    91.56%  |  Test Accuracy:    89.62%
# Training Precision:   91.50%  |  Test Precision:   87.37%
# Training Recall:      91.84%  |  Test Recall:      91.29%
# Training F1:          91.67%  |  Test F1:          89.29%
# Training Time:      31.9137s  |  Test Time:       4.4637s
#
# EPOCH 3                          Total Runtime:   171.45s
# Training Accuracy:    92.06%  |  Test Accuracy:    91.25%
# Training Precision:   90.79%  |  Test Precision:   88.72%
# Training Recall:      93.82%  |  Test Recall:      93.40%
# Training F1:          92.28%  |  Test F1:          91.00%
# Training Time:      29.4651s  |  Test Time:       4.4659s
#
# EPOCH 4                          Total Runtime:   222.25s
# Training Accuracy:    92.72%  |  Test Accuracy:    91.00%
# Training Precision:   90.86%  |  Test Precision:   88.28%
# Training Recall:      95.18%  |  Test Recall:      93.40%
# Training F1:          92.97%  |  Test F1:          90.77%
# Training Time:      28.4821s  |  Test Time:       4.4649s
#
# EPOCH 5                          Total Runtime:   272.09s
# Training Accuracy:    93.31%  |  Test Accuracy:    91.50%
# Training Precision:   92.14%  |  Test Precision:   88.78%
# Training Recall:      94.87%  |  Test Recall:      93.93%
# Training F1:          93.48%  |  Test F1:          91.28%
# Training Time:      27.4895s  |  Test Time:       4.4673s
#
# EPOCH 6                          Total Runtime:   321.46s
# Training Accuracy:    92.97%  |  Test Accuracy:    90.62%
# Training Precision:   90.47%  |  Test Precision:   86.36%
# Training Recall:      96.23%  |  Test Recall:      95.25%
# Training F1:          93.26%  |  Test F1:          90.59%
# Training Time:      27.0309s  |  Test Time:       4.4678s
#
# EPOCH 7                          Total Runtime:   370.16s
# Training Accuracy:    94.16%  |  Test Accuracy:    91.50%
# Training Precision:   92.31%  |  Test Precision:   88.59%
# Training Recall:      96.48%  |  Test Recall:      94.20%
# Training F1:          94.35%  |  Test F1:          91.30%
# Training Time:      26.3620s  |  Test Time:       4.4662s
#
# EPOCH 8                          Total Runtime:   418.48s
# Training Accuracy:    94.81%  |  Test Accuracy:    92.88%
# Training Precision:   95.55%  |  Test Precision:   93.28%
# Training Recall:      94.13%  |  Test Recall:      91.56%
# Training F1:          94.83%  |  Test F1:          92.41%
# Training Time:      25.9878s  |  Test Time:       4.4664s
#
# EPOCH 9                          Total Runtime:   466.57s
# Training Accuracy:    94.75%  |  Test Accuracy:    91.75%
# Training Precision:   94.37%  |  Test Precision:   90.23%
# Training Recall:      95.30%  |  Test Recall:      92.61%
# Training F1:          94.83%  |  Test F1:          91.41%
# Training Time:      25.7684s  |  Test Time:       4.4658s
#
# EPOCH 10                         Total Runtime:   514.19s
# Training Accuracy:    94.47%  |  Test Accuracy:    91.38%
# Training Precision:   92.81%  |  Test Precision:   87.99%
# Training Recall:      96.54%  |  Test Recall:      94.72%
# Training F1:          94.64%  |  Test F1:          91.23%
# Training Time:      25.2832s  |  Test Time:       4.4648s
#
# EPOCH 11                         Total Runtime:   561.91s
# Training Accuracy:    94.59%  |  Test Accuracy:    91.25%
# Training Precision:   92.58%  |  Test Precision:   87.78%
# Training Recall:      97.10%  |  Test Recall:      94.72%
# Training F1:          94.78%  |  Test F1:          91.12%
# Training Time:      25.3935s  |  Test Time:       4.4656s
#
# EPOCH 12                         Total Runtime:   609.60s
# Training Accuracy:    94.84%  |  Test Accuracy:    91.62%
# Training Precision:   93.69%  |  Test Precision:   89.00%
# Training Recall:      96.29%  |  Test Recall:      93.93%
# Training F1:          94.97%  |  Test F1:          91.40%
# Training Time:      25.3524s  |  Test Time:       4.4663s
#
# EPOCH 13                         Total Runtime:   656.98s
# Training Accuracy:    95.19%  |  Test Accuracy:    91.50%
# Training Precision:   93.11%  |  Test Precision:   88.40%
# Training Recall:      97.71%  |  Test Recall:      94.46%
# Training F1:          95.36%  |  Test F1:          91.33%
# Training Time:      25.0209s  |  Test Time:       4.4684s
#
# EPOCH 14                         Total Runtime:   704.12s
# Training Accuracy:    95.97%  |  Test Accuracy:    91.38%
# Training Precision:   94.61%  |  Test Precision:   87.99%
# Training Recall:      97.59%  |  Test Recall:      94.72%
# Training F1:          96.08%  |  Test F1:          91.23%
# Training Time:      24.7884s  |  Test Time:       4.4785s
#
# EPOCH 15                         Total Runtime:   751.19s
# Training Accuracy:    96.62%  |  Test Accuracy:    93.25%
# Training Precision:   96.78%  |  Test Precision:   92.21%
# Training Recall:      96.54%  |  Test Recall:      93.67%
# Training F1:          96.66%  |  Test F1:          92.93%
# Training Time:      24.7375s  |  Test Time:       4.4698s
#
# EPOCH 16                         Total Runtime:   798.10s
# Training Accuracy:    96.41%  |  Test Accuracy:    92.38%
# Training Precision:   97.23%  |  Test Precision:   92.06%
# Training Recall:      95.61%  |  Test Recall:      91.82%
# Training F1:          96.42%  |  Test F1:          91.94%
# Training Time:      24.5650s  |  Test Time:       4.4656s
#
# EPOCH 17                         Total Runtime:   844.68s
# Training Accuracy:    95.97%  |  Test Accuracy:    91.88%
# Training Precision:   94.61%  |  Test Precision:   88.48%
# Training Recall:      97.59%  |  Test Recall:      95.25%
# Training F1:          96.08%  |  Test F1:          91.74%
# Training Time:      24.2484s  |  Test Time:       4.4650s
#
# EPOCH 18                         Total Runtime:   891.06s
# Training Accuracy:    96.69%  |  Test Accuracy:    92.62%
# Training Precision:   97.43%  |  Test Precision:   92.11%
# Training Recall:      95.98%  |  Test Recall:      92.35%
# Training F1:          96.70%  |  Test F1:          92.23%
# Training Time:      24.0281s  |  Test Time:       4.4684s
#
# EPOCH 19                         Total Runtime:   937.32s
# Training Accuracy:    96.88%  |  Test Accuracy:    92.00%
# Training Precision:   96.56%  |  Test Precision:   90.91%
# Training Recall:      97.28%  |  Test Recall:      92.35%
# Training F1:          96.92%  |  Test F1:          91.62%
# Training Time:      23.9174s  |  Test Time:       4.4680s
#
# EPOCH 20                         Total Runtime:   983.37s
# Training Accuracy:    96.91%  |  Test Accuracy:    92.50%
# Training Precision:   98.10%  |  Test Precision:   93.70%
# Training Recall:      95.74%  |  Test Recall:      90.24%
# Training F1:          96.90%  |  Test F1:          91.94%
# Training Time:      23.6618s  |  Test Time:       4.4762s
#
# EPOCH 21                         Total Runtime:  1029.47s
# Training Accuracy:    97.09%  |  Test Accuracy:    92.50%
# Training Precision:   97.51%  |  Test Precision:   91.43%
# Training Recall:      96.72%  |  Test Recall:      92.88%
# Training F1:          97.11%  |  Test F1:          92.15%
# Training Time:      23.7588s  |  Test Time:       4.4713s
#
# EPOCH 22                         Total Runtime:  1075.44s
# Training Accuracy:    96.53%  |  Test Accuracy:    92.38%
# Training Precision:   95.42%  |  Test Precision:   89.95%
# Training Recall:      97.84%  |  Test Recall:      94.46%
# Training F1:          96.61%  |  Test F1:          92.15%
# Training Time:      23.6310s  |  Test Time:       4.4651s
#
# EPOCH 23                         Total Runtime:  1121.31s
# Training Accuracy:    97.44%  |  Test Accuracy:    92.50%
# Training Precision:   98.06%  |  Test Precision:   92.53%
# Training Recall:      96.85%  |  Test Recall:      91.56%
# Training F1:          97.45%  |  Test F1:          92.04%
# Training Time:      23.5362s  |  Test Time:       4.4685s
#
# EPOCH 24                         Total Runtime:  1167.35s
# Training Accuracy:    97.06%  |  Test Accuracy:    93.50%
# Training Precision:   97.74%  |  Test Precision:   93.83%
# Training Recall:      96.42%  |  Test Recall:      92.35%
# Training F1:          97.08%  |  Test F1:          93.09%
# Training Time:      23.7013s  |  Test Time:       4.4661s
#
# EPOCH 25                         Total Runtime:  1213.45s
# Training Accuracy:    96.34%  |  Test Accuracy:    92.12%
# Training Precision:   97.96%  |  Test Precision:   92.70%
# Training Recall:      94.75%  |  Test Recall:      90.50%
# Training F1:          96.32%  |  Test F1:          91.59%
# Training Time:      23.7389s  |  Test Time:       4.4748s
#
# EPOCH 26                         Total Runtime:  1259.43s
# Training Accuracy:    96.41%  |  Test Accuracy:    93.00%
# Training Precision:   99.34%  |  Test Precision:   95.24%
# Training Recall:      93.51%  |  Test Recall:      89.71%
# Training F1:          96.34%  |  Test F1:          92.39%
# Training Time:      23.6147s  |  Test Time:       4.4715s
#
# EPOCH 27                         Total Runtime:  1305.13s
# Training Accuracy:    97.19%  |  Test Accuracy:    93.25%
# Training Precision:   96.70%  |  Test Precision:   91.77%
# Training Recall:      97.78%  |  Test Recall:      94.20%
# Training F1:          97.23%  |  Test F1:          92.97%
# Training Time:      23.3710s  |  Test Time:       4.4671s
#
# EPOCH 28                         Total Runtime:  1350.72s
# Training Accuracy:    97.62%  |  Test Accuracy:    93.38%
# Training Precision:   98.07%  |  Test Precision:   92.89%
# Training Recall:      97.22%  |  Test Recall:      93.14%
# Training F1:          97.64%  |  Test F1:          93.02%
# Training Time:      23.2366s  |  Test Time:       4.4694s
#
# EPOCH 29                         Total Runtime:  1396.25s
# Training Accuracy:    97.28%  |  Test Accuracy:    92.62%
# Training Precision:   97.75%  |  Test Precision:   93.01%
# Training Recall:      96.85%  |  Test Recall:      91.29%
# Training F1:          97.30%  |  Test F1:          92.14%
# Training Time:      23.1984s  |  Test Time:       4.4660s
#
# EPOCH 30                         Total Runtime:  1441.71s
# Training Accuracy:    97.62%  |  Test Accuracy:    91.88%
# Training Precision:   96.90%  |  Test Precision:   88.67%
# Training Recall:      98.45%  |  Test Recall:      94.99%
# Training F1:          97.67%  |  Test F1:          91.72%
# Training Time:      23.1264s  |  Test Time:       4.4689s
#
# Clause #0 W: (27 -104) NOT x12 AND NOT x46 AND NOT x50 AND NOT x486
# Number of literals: 4
# Clause #1 W: (175 -191) NOT x485
# Number of literals: 1
# Clause #2 W: (-104 19) NOT x333
# Number of literals: 1
# Clause #3 W: (-26 -40) NOT x14 AND NOT x187 AND NOT x413
# Number of literals: 3
# Clause #4 W: (-47 76) NOT x306 AND NOT x365
# Number of literals: 2
# Clause #5 W: (97 -180) NOT x124
# Number of literals: 1
# Clause #6 W: (-65 60) NOT x89 AND NOT x458
# Number of literals: 2
# Clause #7 W: (80 -66) NOT x323 AND NOT x371
# Number of literals: 2
# Clause #8 W: (32 -4)
# Number of literals: 0
# Clause #9 W: (-81 44)
# Number of literals: 0
# [[ 54]
#  [291]
#  [430]
#  [206]
#  [287]
#  [460]
#  [387]
#  [388]
#  [150]]
# {'right': 0, 'down_right': 1, 'down_left': 2, 'left': 3, 'down_right_O_chain': 4, 'down_right_X_chain': 5, 'right_X_chain': 6, 'up_left': 7, 'up_right': 8, 'left_X_chain': 9, 'up_left_O_chain': 10, 'up_left_X_chain': 11, 'down_left_X_chain': 12, 'right_O_chain': 13, 'down_left_O_chain': 14, 'left_O_chain': 15, 'up_right_X_chain': 16, 'up_right_O_chain': 17}
