# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib import ticker
import seaborn as sns
import numpy as np
from time import time
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,recall_score, precision_score, f1_score, confusion_matrix
from GraphTsetlinMachine.tm import MultiClassGraphTsetlinMachine
from GraphTsetlinMachine.graphs import Graphs   

# For when not using command line arguments:
import argparse
parser = argparse.ArgumentParser()
parser.add_argument('-f') # Dummy argument

#plt.switch_backend('Agg') # Disable plots if backend not interactive

board_count = 0
board_size = 0
board_type = ""
boards = []
labels = []
label_names = ["X_win", "O_win"]

# Load dataset
with open("hex_complete_5x5_4000_mostly_filled.txt") as f:
    
    board_count, board_size, empty = [int(x) for x in f.readline().split(' ')]
    
    if "barely" in f.name:
        board_type = f"Barely filled (>={empty} empty cells)"
    elif "mostly" in f.name:
        board_type = f"Mostly filled (<={empty} empty cells)"
    else: board_type = f"Randomly filled ({empty} empty cells)"

    boards = np.empty([board_count, board_size, board_size], dtype=str)
    current_board = 0
    row = 0
    
    X_count = 0
    O_count = 0
    
    for line in f:
        if line == '\n':
            continue
        if row < board_size:
            for column, char in enumerate(line.rstrip()):
                boards[current_board][row][column] = char
            row += 1
        else:
            row = 0
            
            # Count wins to see if dataset is balanced
            if int(line.rstrip()) == 0:
                X_count += 1
            else:
                O_count += 1
            
            labels.append(int(line.rstrip()))
            current_board += 1

# %%
def generate_five_moves_before(boards, labels):
 
    five_moves_boards = []
    five_moves_labels = []

    for game, label in zip(boards, labels):
        total_moves = np.sum(game != '*')  
        if total_moves > 5:  
            intermediate_state = game.copy()
            empty_count = 5  
            for i in range(len(game)):
                for j in range(len(game[i])):
                    if intermediate_state[i, j] != '*' and empty_count > 0:
                        intermediate_state[i, j] = '*' 
                        empty_count -= 1
            five_moves_boards.append(intermediate_state)
            five_moves_labels.append(label)

    return np.array(five_moves_boards), np.array(five_moves_labels)

# %%
def plot_metrics(accuracy_train, precision_train, recall_train, f1_train, accuracy_test, precision_test, recall_test, f1_test, epochs, board_size, board_type):
   
    dataset_types = ["Train", "Test"]
    
    x_values = np.arange(1, epochs+1, 1)
    fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharey='all', constrained_layout=True)
    fig.suptitle(f'GTM Metrics for Training and Testing, {board_size}x{board_size}, Five Moves Before End,\n {epochs} Epochs, {board_type}', fontweight='bold')
    
    blue = [(0.6, 0.76, 0.98), (0, 0.21, 0.46)] 
    orange = [(255/255, 197/255, 165/255), (200/255, 71/255, 0/255)]
    red = [(255/255, 176/255, 165/255), (180/255, 21/255, 0/255)]
    purple = [(219/255, 165/255, 255/255), (119/255, 0/255, 200/255)]
    blue_cm = mpl.colors.LinearSegmentedColormap.from_list('custom_blue', blue, N=10)
    orange_cm = mpl.colors.LinearSegmentedColormap.from_list('custom_orange', orange, N=10)
    red_cm = mpl.colors.LinearSegmentedColormap.from_list('custom_red', red, N=10)
    purple_cm = mpl.colors.LinearSegmentedColormap.from_list('custom_purple', purple, N=10)

    colormaps = [blue_cm, orange_cm, red_cm, purple_cm]

    accuracy_colors = colormaps[0](np.linspace(0, 1, len(dataset_types)))
    precision_colors = colormaps[1](np.linspace(0, 1, len(dataset_types)))
    recall_colors = colormaps[2](np.linspace(0, 1, len(dataset_types)))
    f1_colors = colormaps[3](np.linspace(0, 1, len(dataset_types)))

    ax1.set_title('Accuracy')
    ax2.set_title('Precision')
    ax3.set_title('Recall')
    ax4.set_title('F1')
    
    for index, ax in enumerate (fig.get_axes()):
        ax.set(xlabel='$\it{Epoch}$', ylabel='$\it{Score}$')
        ax.xaxis.set_major_locator(mpl.ticker.MaxNLocator(integer=True))
        ax.label_outer()
        ax.grid()
        
        bounds = [0, 1, 2]
        norm = mpl.colors.BoundaryNorm(bounds, colormaps[index].N)
        scalar_mappable = plt.cm.ScalarMappable(cmap=colormaps[index], norm=norm)
        
        clb = plt.colorbar(scalar_mappable, ax=ax)
        clb.ax.set_xlabel('Dataset', fontsize=7, loc='left')
        clb.ax.set_yticks([0.5, 1.5])
        clb.ax.set_yticklabels(dataset_types, fontsize=7)

    ax1.plot(x_values, accuracy_train, color=accuracy_colors[0])
    ax2.plot(x_values, precision_train, color=precision_colors[0])
    ax3.plot(x_values, recall_train, color=recall_colors[0])
    ax4.plot(x_values, f1_train, color=f1_colors[0])
    
    ax1.plot(x_values, accuracy_test, color=accuracy_colors[1])
    ax2.plot(x_values, precision_test, color=precision_colors[1])
    ax3.plot(x_values, recall_test, color=recall_colors[1])
    ax4.plot(x_values, f1_test, color=f1_colors[1])
    
    ax.set_ylim(top=1.001)
    
    fig.savefig(f"metrics_{board_size}x{board_size}_Five_moves{epochs}_epochs_{board_type.split(' ')[0]}.png", dpi=1200)
    fig.show()


def main():
    # Track runtime
    start_time = time()
    
    # Parameters:
    epochs = 30
    number_of_clauses = 2000
    T = 3500
    s = 2.1
    depth = 3
    hypervector_size = 512
    hypervector_bits = 1
    message_size = 8192
    message_bits = 1
    max_included_literals = 32
    
    # Print info about dataset
    print(f"Dataset:\n"
      f"Board size:  {board_size}x{board_size}\n"
      f"Board count: {board_count}\n"
      f"Board type:  {board_type}\n"
      f"X wins:      {X_count}\n"
      f"O wins:      {O_count}\n"
      f"")
    
    print("X: Vertical   - win=0\n"
          "O: Horizontal - win=1\n")
    
    print("Game 1 & 2:")              
    print(boards[:2]) 
    print()
    print("Game 1 & 2 Results:")
    print(labels[:2])
    print("\n")
    
    #* Split dataset
  
    boards_5_before, labels_5_before = generate_five_moves_before(boards, labels)
    X_train_5_before, X_test_5_before, Y_train_5_before, Y_test_5_before = train_test_split(boards_5_before, labels_5_before, test_size=0.20, random_state=42)




    #************************************** Initialize graphs for training data ***************************************
    graphs_train = Graphs(
        X_train_5_before.shape[0],
        symbols=['X', 'O', '*', 'Xw', 'Ow', 'Xc', 'Xs', 'Oc', 'Os'],
        hypervector_size=hypervector_size, # Number of features
        hypervector_bits=hypervector_bits
    )
    
    for graph_id in range(X_train_5_before.shape[0]):
        graphs_train.set_number_of_graph_nodes(graph_id, board_size*board_size)
    
    # Add nodes
    graphs_train.prepare_node_configuration()
    
    for graph_id in range( X_train_5_before.shape[0]):
        for i in range(board_size):
            for j in range(board_size):
                if j == 0 or j == board_size-1 or i == 0 or i == board_size-1:
                    # Along borders of board
                    if (i == 0 and j == 0) or (i == board_size-1 and j == board_size-1):
                        number_of_outgoing_edges = 2 # Top left / bottom right
                        graphs_train.add_graph_node(graph_id, f"n{i}{j}", number_of_outgoing_edges)
                    elif (i == 0 and j == board_size-1) or (i == board_size-1 and j == 0):
                        number_of_outgoing_edges = 3 # Top right / bottom left
                        graphs_train.add_graph_node(graph_id, f"n{i}{j}", number_of_outgoing_edges)
                    else:
                        number_of_outgoing_edges = 4 # Between corners
                        graphs_train.add_graph_node(graph_id, f"n{i}{j}", number_of_outgoing_edges)
                else:
                    number_of_outgoing_edges = 6 # Middle
                    graphs_train.add_graph_node(graph_id, f"n{i}{j}", number_of_outgoing_edges)


    # Add edges
    graphs_train.prepare_edge_configuration()
    
    # Add node properties and class labels
    for graph_id in range(X_train_5_before.shape[0]):
        for i in range(board_size):
            for j in range(board_size):
                graphs_train.add_graph_node_property(graph_id, f"n{i}{j}",  X_train_5_before[graph_id][i][j])
                
                # Wall nodes top bottom
                if i == 0 or i == board_size-1:
                    graphs_train.add_graph_node_property(graph_id, f"n{i}{j}", 'Xw')
                    
                # Wall nodes left right
                if j == 0 or j == board_size-1:
                    graphs_train.add_graph_node_property(graph_id, f"n{i}{j}", 'Ow')
                    
                    
    for graph_id in range(X_train_5_before.shape[0]):
        for i in range(board_size):
            for j in range(board_size):
                # Specify edge between nodes as a "chain" if it connects two pieces of the same type
                chained = 0
                if j != board_size-1:
                    if  X_train_5_before[graph_id][i][j+1] ==  X_train_5_before[graph_id][i][j] != '*':
                        # Right neighbour of same type
                        graphs_train.add_graph_node_edge(graph_id, f"n{i}{j}", f"n{i}{j+1}", f"right_{ X_train_5_before[graph_id][i][j]}_chain")
                        chained = 1
                    else:
                        # Attempt to dynamically adjust number of node edges
                        # num = graphs_train.number_of_graph_node_edges[graphs_train.node_index[graph_id] + graphs_train.graph_node_id[graph_id][f'n{i}{j}']]
                        # graphs_train.number_of_graph_node_edges[graphs_train.node_index[graph_id] + graphs_train.graph_node_id[graph_id][f'n{i}{j}']] = num - 1
                        graphs_train.add_graph_node_edge(graph_id, f"n{i}{j}", f"n{i}{j+1}", "right") # Right
                
                if i != board_size-1:
                    if  X_train_5_before[graph_id][i+1][j] ==  X_train_5_before[graph_id][i][j] != '*':
                        graphs_train.add_graph_node_edge(graph_id, f"n{i}{j}", f"n{i+1}{j}", f"down_right_{ X_train_5_before[graph_id][i][j]}_chain")
                        chained = 1
                    else:
                        graphs_train.add_graph_node_edge(graph_id, f"n{i}{j}", f"n{i+1}{j}", "down_right") # Down-right
                    
                if j != 0 and i != board_size-1:
                    if  X_train_5_before[graph_id][i+1][j-1] ==  X_train_5_before[graph_id][i][j] != '*':
                        graphs_train.add_graph_node_edge(graph_id, f"n{i}{j}", f"n{i+1}{j-1}", f"down_left_{ X_train_5_before[graph_id][i][j]}_chain")
                        chained = 1
                    else:
                        graphs_train.add_graph_node_edge(graph_id, f"n{i}{j}", f"n{i+1}{j-1}", "down_left") # Down-left
                    
                if j != 0:
                    if  X_train_5_before[graph_id][i][j-1] ==  X_train_5_before[graph_id][i][j] != '*':
                        graphs_train.add_graph_node_edge(graph_id, f"n{i}{j}", f"n{i}{j-1}", f"left_{ X_train_5_before[graph_id][i][j]}_chain")
                        chained = 1
                    else:
                        graphs_train.add_graph_node_edge(graph_id, f"n{i}{j}", f"n{i}{j-1}", "left") # Left
                    
                if i != 0:
                    if  X_train_5_before[graph_id][i-1][j] ==  X_train_5_before[graph_id][i][j] != '*':
                        graphs_train.add_graph_node_edge(graph_id, f"n{i}{j}", f"n{i-1}{j}", f"up_left_{X_train_5_before[graph_id][i][j]}_chain")
                        chained = 1
                    else:
                        graphs_train.add_graph_node_edge(graph_id, f"n{i}{j}", f"n{i-1}{j}", "up_left") # Up-left
                
                if i != 0 and j != board_size-1:
                    if X_train_5_before[graph_id][i-1][j+1] == X_train_5_before[graph_id][i][j] != '*':
                        graphs_train.add_graph_node_edge(graph_id, f"n{i}{j}", f"n{i-1}{j+1}", f"up_right_{X_train_5_before[graph_id][i][j]}_chain")
                        chained = 1
                    else:
                        graphs_train.add_graph_node_edge(graph_id, f"n{i}{j}", f"n{i-1}{j+1}", "up_right") # Up-right
                        
                # Add property of either "chained" or "solo" to node as well
                if chained == 1:
                    graphs_train.add_graph_node_property(graph_id, f"n{i}{j}", f'{X_train_5_before[graph_id][i][j]}c')
                elif X_train_5_before[graph_id][i][j] != '*':
                    graphs_train.add_graph_node_property(graph_id, f"n{i}{j}", f'{X_train_5_before[graph_id][i][j]}s')
                    
    graphs_train.encode()
    
    
    #************************************** Initialize graphs for test data ***************************************
    graphs_test = Graphs(X_test_5_before.shape[0], init_with=graphs_train)
    
    for graph_id in range(X_test_5_before.shape[0]):
        graphs_test.set_number_of_graph_nodes(graph_id, board_size*board_size)
    
    # Add nodes
    graphs_test.prepare_node_configuration()
    
    for graph_id in range(X_test_5_before.shape[0]):
        for i in range(board_size):
            for j in range(board_size):
                if j == 0 or j == board_size-1 or i == 0 or i == board_size-1:
                    # Along borders of board
                    if (i == 0 and j == 0) or (i == board_size-1 and j == board_size-1):
                        number_of_outgoing_edges = 2 # Top left / bottom right
                        graphs_test.add_graph_node(graph_id, f"n{i}{j}", number_of_outgoing_edges)
                    elif (i == 0 and j == board_size-1) or (i == board_size-1 and j == 0):
                        number_of_outgoing_edges = 3 # Top right / bottom left
                        graphs_test.add_graph_node(graph_id, f"n{i}{j}", number_of_outgoing_edges)
                    else:
                        number_of_outgoing_edges = 4 # Between corners
                        graphs_test.add_graph_node(graph_id, f"n{i}{j}", number_of_outgoing_edges)
                else:
                    number_of_outgoing_edges = 6 # Middle
                    graphs_test.add_graph_node(graph_id, f"n{i}{j}", number_of_outgoing_edges)


    # Add edges
    graphs_test.prepare_edge_configuration()
    
    # Add node properties and class labels
    for graph_id in range(X_test_5_before.shape[0]):
        for i in range(board_size):
            for j in range(board_size):
                graphs_test.add_graph_node_property(graph_id, f"n{i}{j}", X_test_5_before[graph_id][i][j])
                
                # Wall nodes top bottom
                if i == 0 or i == board_size-1:
                    graphs_test.add_graph_node_property(graph_id, f"n{i}{j}", 'Xw')
                    
                # Wall nodes left right
                if j == 0 or j == board_size-1:
                    graphs_test.add_graph_node_property(graph_id, f"n{i}{j}", 'Ow')
                    
                    
    for graph_id in range(X_test_5_before.shape[0]):
        for i in range(board_size):
            for j in range(board_size):
                # Specify edge between nodes as a "chain" if it connects two pieces of the same type
                chained = 0
                if j != board_size-1:
                    if X_test_5_before[graph_id][i][j+1] == X_test_5_before[graph_id][i][j] != '*':
                        # Right neighbour of same type
                        graphs_test.add_graph_node_edge(graph_id, f"n{i}{j}", f"n{i}{j+1}", f"right_{X_test_5_before[graph_id][i][j]}_chain")
                        chained = 1
                    else:
                        graphs_test.add_graph_node_edge(graph_id, f"n{i}{j}", f"n{i}{j+1}", "right") # Right
                
                if i != board_size-1:
                    if X_test_5_before[graph_id][i+1][j] == X_test_5_before[graph_id][i][j] != '*':
                        graphs_test.add_graph_node_edge(graph_id, f"n{i}{j}", f"n{i+1}{j}", f"down_right_{X_test_5_before[graph_id][i][j]}_chain")
                        chained = 1
                    else:
                        graphs_test.add_graph_node_edge(graph_id, f"n{i}{j}", f"n{i+1}{j}", "down_right") # Down-right
                    
                if j != 0 and i != board_size-1:
                    if X_test_5_before[graph_id][i+1][j-1] == X_test_5_before[graph_id][i][j] != '*':
                        graphs_test.add_graph_node_edge(graph_id, f"n{i}{j}", f"n{i+1}{j-1}", f"down_left_{X_test_5_before[graph_id][i][j]}_chain")
                        chained = 1
                    else:
                        graphs_test.add_graph_node_edge(graph_id, f"n{i}{j}", f"n{i+1}{j-1}", "down_left") # Down-left
                    
                if j != 0:
                    if X_test_5_before[graph_id][i][j-1] == X_test_5_before[graph_id][i][j] != '*':
                        graphs_test.add_graph_node_edge(graph_id, f"n{i}{j}", f"n{i}{j-1}", f"left_{X_test_5_before[graph_id][i][j]}_chain")
                        chained = 1
                    else:
                        graphs_test.add_graph_node_edge(graph_id, f"n{i}{j}", f"n{i}{j-1}", "left") # Left
                    
                if i != 0:
                    if X_test_5_before[graph_id][i-1][j] == X_test_5_before[graph_id][i][j] != '*':
                        graphs_test.add_graph_node_edge(graph_id, f"n{i}{j}", f"n{i-1}{j}", f"up_left_{X_test_5_before[graph_id][i][j]}_chain")
                        chained = 1
                    else:
                        graphs_test.add_graph_node_edge(graph_id, f"n{i}{j}", f"n{i-1}{j}", "up_left") # Up-left
                
                if i != 0 and j != board_size-1:
                    if X_test_5_before[graph_id][i-1][j+1] == X_test_5_before[graph_id][i][j] != '*':
                        graphs_test.add_graph_node_edge(graph_id, f"n{i}{j}", f"n{i-1}{j+1}", f"up_right_{X_test_5_before[graph_id][i][j]}_chain")
                        chained = 1
                    else:
                        graphs_test.add_graph_node_edge(graph_id, f"n{i}{j}", f"n{i-1}{j+1}", "up_right") # Up-right
                        
                # Add property of either "chained" or "solo" to node as well
                if chained == 1:
                    graphs_test.add_graph_node_property(graph_id, f"n{i}{j}", f'{X_test_5_before[graph_id][i][j]}c')
                elif X_test_5_before[graph_id][i][j] != '*':
                    graphs_test.add_graph_node_property(graph_id, f"n{i}{j}", f'{X_test_5_before[graph_id][i][j]}s')
            
    graphs_test.encode()
    
    
    #************************************** Initialize Graph Tsetlin Machine ***************************************
    tm = MultiClassGraphTsetlinMachine(
        number_of_clauses = number_of_clauses,
        T = T,
        s = s,
        depth = depth,
        message_size = message_size,
        message_bits = message_bits,
        max_included_literals = max_included_literals,
        grid=(16*13,1,1)
    )
    
    
    # For plotting performance metrics
    acc_test_seq = []
    acc_train_seq = []
    
    precision_train_seq = []
    precision_test_seq = []
    
    recall_train_seq = []
    recall_test_seq = []
    
    f1_score_train_seq = []
    f1_score_test_seq = []
    
    cm = []
    
    
    # For each epoch:
    for i in range(epochs):
        
        start_training = time()
        tm.fit(graphs_train, Y_train_5_before, epochs = 1, incremental=True)
        stop_training = time()
        
        start_testing = time()
        result_test = tm.predict(graphs_test)
        stop_testing = time()
        
        result_train = tm.predict(graphs_train)
    
       
        # Performance metrics
        acc_train = accuracy_score(Y_train_5_before, result_train)
        acc_test = accuracy_score(Y_test_5_before, result_test)
        acc_train_seq.append(acc_train)
        acc_test_seq.append(acc_test)
        
        precision_train = precision_score(Y_train_5_before, result_train)
        precision_test = precision_score(Y_test_5_before, result_test)
        precision_train_seq.append(precision_train)
        precision_test_seq.append(precision_test)
        
        recall_train = recall_score(Y_train_5_before, result_train)
        recall_test = recall_score(Y_test_5_before, result_test)
        recall_train_seq.append(recall_train)
        recall_test_seq.append(recall_test)
        
        f1_score_train = f1_score(Y_train_5_before, result_train)
        f1_score_test = f1_score(Y_test_5_before, result_test)
        f1_score_train_seq.append(f1_score_train)
        f1_score_test_seq.append(f1_score_test)
        
        if i == epochs-1:
            cm = confusion_matrix(Y_test_5_before, result_test)

        
        print(f"\nEPOCH {i+1: <24}   Total Runtime: {time()-start_time:8.2f}s\n"
              f"Training Accuracy:  {100*acc_train:7.2f}%  |  Test Accuracy:  {100*acc_test:7.2f}%  \n"
              f"Training Precision: {100*precision_train:7.2f}%  |  Test Precision: {100*precision_test:7.2f}%  \n"
              f"Training Recall:    {100*recall_train:7.2f}%  |  Test Recall:    {100*recall_test:7.2f}%  \n"
              f"Training F1:        {100*f1_score_train:7.2f}%  |  Test F1:        {100*f1_score_test:7.2f}%  \n"
              f"Training Time:      {stop_training-start_training:7.4f}s  |  Test Time:      {stop_testing-start_testing:7.4f}s")
        
        
    # Plot cm
    plt.figure()
    sns.heatmap(cm, annot=True, fmt='d', xticklabels=label_names, yticklabels=label_names)
    plt.title(f"Confusion Matrix for Test Predictions of {board_size}x{board_size} Five Moves Before End,\n {epochs} Epochs, {board_type}", fontweight='bold')
    plt.xlabel("Predicted Result", fontweight='bold')
    plt.ylabel("Actual Result", fontweight='bold')
    plt.savefig(f"cm_{board_size}x{board_size}_Five_Moves_{epochs}_epochs_{board_type.split(' ')[0]}.png", dpi=1200)
    plt.close()
 
    # Plot metrics
    plt.style.use('default')
    plot_metrics(acc_train_seq, precision_train_seq, recall_train_seq, f1_score_train_seq, acc_test_seq, precision_test_seq, recall_test_seq, f1_score_test_seq, epochs, board_size, board_type)
        
        
    # Print misc. info
    weights = tm.get_state()[1].reshape(2, -1)
    print()
    for i in range(tm.number_of_clauses):
        if i < 10:
            print("Clause #%d W: (%d %d)" % (i, weights[0, i], weights[1, i]), end=' ')
            l = []
            for k in range(hypervector_size * 2):
                if tm.ta_action(0, i, k):
                    if k < hypervector_size:
                        l.append("x%d" % (k))
                    else:
                        l.append("NOT x%d" % (k - hypervector_size))
                    
            print(" AND ".join(l))
            print(f"Number of literals: {len(l)}")
        
    print(graphs_train.hypervectors)
    #print(tm.hypervectors)
    print(graphs_test.edge_type_id)


if __name__ == "__main__":
    main()
# Out:
# Dataset:
# Board size:  5x5
# Board count: 4000
# Board type:  Mostly filled (<=2 empty cells)
# X wins:      2003
# O wins:      1997
#
# X: Vertical   - win=0
# O: Horizontal - win=1
#
# Game 1 & 2:
# [[['X' 'X' 'X' 'O' 'X']
#   ['X' 'O' 'X' 'O' 'O']
#   ['O' 'O' 'X' 'X' 'O']
#   ['O' 'X' 'O' 'X' 'O']
#   ['O' 'X' 'X' 'O' 'X']]
#
#  [['X' 'X' 'O' 'X' 'O']
#   ['X' 'X' 'O' 'O' 'X']
#   ['O' 'X' 'O' 'X' 'X']
#   ['O' 'X' '*' 'O' 'X']
#   ['*' 'X' 'O' 'O' 'O']]]
#
# Game 1 & 2 Results:
# [0, 0]
#
#
# Initialization of sparse structure.
#
# EPOCH 1                          Total Runtime:   140.35s
# Training Accuracy:    79.91%  |  Test Accuracy:    78.62%
# Training Precision:   88.12%  |  Test Precision:   85.62%
# Training Recall:      69.65%  |  Test Recall:      65.96%
# Training F1:          77.80%  |  Test F1:          74.52%
# Training Time:      76.3349s  |  Test Time:      11.5067s
#
# EPOCH 2                          Total Runtime:   269.18s
# Training Accuracy:    83.28%  |  Test Accuracy:    79.62%
# Training Precision:   89.85%  |  Test Precision:   82.73%
# Training Recall:      75.46%  |  Test Recall:      72.03%
# Training F1:          82.03%  |  Test F1:          77.01%
# Training Time:      73.6000s  |  Test Time:      11.1415s
#
# EPOCH 3                          Total Runtime:   395.23s
# Training Accuracy:    83.53%  |  Test Accuracy:    79.50%
# Training Precision:   89.96%  |  Test Precision:   83.70%
# Training Recall:      75.90%  |  Test Recall:      70.45%
# Training F1:          82.33%  |  Test F1:          76.50%
# Training Time:      71.8229s  |  Test Time:      10.8980s
#
# EPOCH 4                          Total Runtime:   519.90s
# Training Accuracy:    82.53%  |  Test Accuracy:    78.88%
# Training Precision:   83.20%  |  Test Precision:   77.49%
# Training Recall:      82.01%  |  Test Recall:      78.10%
# Training F1:          82.60%  |  Test F1:          77.79%
# Training Time:      70.9977s  |  Test Time:      10.8001s
#
# EPOCH 5                          Total Runtime:   643.75s
# Training Accuracy:    83.88%  |  Test Accuracy:    79.88%
# Training Precision:   87.95%  |  Test Precision:   81.32%
# Training Recall:      78.92%  |  Test Recall:      74.67%
# Training F1:          83.19%  |  Test F1:          77.85%
# Training Time:      70.3862s  |  Test Time:      10.7474s
#
# EPOCH 6                          Total Runtime:   767.06s
# Training Accuracy:    81.62%  |  Test Accuracy:    75.12%
# Training Precision:   78.90%  |  Test Precision:   69.91%
# Training Recall:      86.90%  |  Test Recall:      83.38%
# Training F1:          82.71%  |  Test F1:          76.05%
# Training Time:      69.9404s  |  Test Time:      10.7121s
#
# EPOCH 7                          Total Runtime:   889.56s
# Training Accuracy:    83.53%  |  Test Accuracy:    76.50%
# Training Precision:   83.12%  |  Test Precision:   73.12%
# Training Recall:      84.61%  |  Test Recall:      79.68%
# Training F1:          83.86%  |  Test F1:          76.26%
# Training Time:      69.3761s  |  Test Time:      10.6740s
#
# EPOCH 8                          Total Runtime:  1010.80s
# Training Accuracy:    84.31%  |  Test Accuracy:    79.62%
# Training Precision:   85.27%  |  Test Precision:   77.98%
# Training Recall:      83.37%  |  Test Recall:      79.42%
# Training F1:          84.31%  |  Test F1:          78.69%
# Training Time:      68.5197s  |  Test Time:      10.5944s
#
# EPOCH 9                          Total Runtime:  1131.95s
# Training Accuracy:    85.06%  |  Test Accuracy:    79.50%
# Training Precision:   87.01%  |  Test Precision:   78.36%
# Training Recall:      82.82%  |  Test Recall:      78.36%
# Training F1:          84.86%  |  Test F1:          78.36%
# Training Time:      68.4622s  |  Test Time:      10.5127s
#
# EPOCH 10                         Total Runtime:  1253.25s
# Training Accuracy:    85.44%  |  Test Accuracy:    79.38%
# Training Precision:   87.60%  |  Test Precision:   78.61%
# Training Recall:      82.94%  |  Test Recall:      77.57%
# Training F1:          85.21%  |  Test F1:          78.09%
# Training Time:      68.7093s  |  Test Time:      10.5163s
#
# EPOCH 11                         Total Runtime:  1373.80s
# Training Accuracy:    86.00%  |  Test Accuracy:    80.62%
# Training Precision:   90.79%  |  Test Precision:   82.00%
# Training Recall:      80.47%  |  Test Recall:      75.73%
# Training F1:          85.32%  |  Test F1:          78.74%
# Training Time:      68.0859s  |  Test Time:      10.3331s
#
# EPOCH 12                         Total Runtime:  1493.99s
# Training Accuracy:    86.12%  |  Test Accuracy:    78.88%
# Training Precision:   88.42%  |  Test Precision:   77.93%
# Training Recall:      83.50%  |  Test Recall:      77.31%
# Training F1:          85.89%  |  Test F1:          77.62%
# Training Time:      67.7068s  |  Test Time:      10.3287s
#
# EPOCH 13                         Total Runtime:  1613.97s
# Training Accuracy:    84.47%  |  Test Accuracy:    79.25%
# Training Precision:   83.22%  |  Test Precision:   76.43%
# Training Recall:      86.77%  |  Test Recall:      81.27%
# Training F1:          84.96%  |  Test F1:          78.77%
# Training Time:      67.4609s  |  Test Time:      10.4292s
#
# EPOCH 14                         Total Runtime:  1733.36s
# Training Accuracy:    85.50%  |  Test Accuracy:    78.50%
# Training Precision:   86.47%  |  Test Precision:   75.68%
# Training Recall:      84.55%  |  Test Recall:      80.47%
# Training F1:          85.50%  |  Test F1:          78.01%
# Training Time:      66.9819s  |  Test Time:      10.3457s
#
# EPOCH 15                         Total Runtime:  1852.90s
# Training Accuracy:    84.69%  |  Test Accuracy:    76.62%
# Training Precision:   82.53%  |  Test Precision:   72.54%
# Training Recall:      88.44%  |  Test Recall:      81.53%
# Training F1:          85.38%  |  Test F1:          76.77%
# Training Time:      67.0345s  |  Test Time:      10.4678s
#
# EPOCH 16                         Total Runtime:  1971.95s
# Training Accuracy:    85.72%  |  Test Accuracy:    77.50%
# Training Precision:   88.88%  |  Test Precision:   76.25%
# Training Recall:      82.01%  |  Test Recall:      76.25%
# Training F1:          85.31%  |  Test F1:          76.25%
# Training Time:      66.5843s  |  Test Time:      10.3995s
#
# EPOCH 17                         Total Runtime:  2090.61s
# Training Accuracy:    84.91%  |  Test Accuracy:    77.38%
# Training Precision:   83.21%  |  Test Precision:   72.50%
# Training Recall:      87.89%  |  Test Recall:      84.17%
# Training F1:          85.48%  |  Test F1:          77.90%
# Training Time:      66.2286s  |  Test Time:      10.3463s
#
# EPOCH 18                         Total Runtime:  2209.25s
# Training Accuracy:    85.34%  |  Test Accuracy:    76.12%
# Training Precision:   83.97%  |  Test Precision:   71.46%
# Training Recall:      87.76%  |  Test Recall:      82.59%
# Training F1:          85.83%  |  Test F1:          76.62%
# Training Time:      66.1866s  |  Test Time:      10.2724s
#
# EPOCH 19                         Total Runtime:  2327.92s
# Training Accuracy:    86.66%  |  Test Accuracy:    77.62%
# Training Precision:   88.90%  |  Test Precision:   75.77%
# Training Recall:      84.12%  |  Test Recall:      77.57%
# Training F1:          86.44%  |  Test F1:          76.66%
# Training Time:      66.1408s  |  Test Time:      10.3688s
#
# EPOCH 20                         Total Runtime:  2446.31s
# Training Accuracy:    86.06%  |  Test Accuracy:    76.75%
# Training Precision:   86.08%  |  Test Precision:   73.25%
# Training Recall:      86.40%  |  Test Recall:      80.21%
# Training F1:          86.24%  |  Test F1:          76.57%
# Training Time:      65.7794s  |  Test Time:      10.3973s
#
# EPOCH 21                         Total Runtime:  2564.35s
# Training Accuracy:    86.69%  |  Test Accuracy:    79.50%
# Training Precision:   87.82%  |  Test Precision:   78.07%
# Training Recall:      85.54%  |  Test Recall:      78.89%
# Training F1:          86.66%  |  Test F1:          78.48%
# Training Time:      65.3952s  |  Test Time:      10.4653s
#
# EPOCH 22                         Total Runtime:  2682.32s
# Training Accuracy:    85.19%  |  Test Accuracy:    76.62%
# Training Precision:   83.49%  |  Test Precision:   72.43%
# Training Recall:      88.13%  |  Test Recall:      81.79%
# Training F1:          85.75%  |  Test F1:          76.83%
# Training Time:      65.2692s  |  Test Time:      10.5409s
#
# EPOCH 23                         Total Runtime:  2799.83s
# Training Accuracy:    86.59%  |  Test Accuracy:    77.75%
# Training Precision:   87.27%  |  Test Precision:   75.57%
# Training Recall:      86.03%  |  Test Recall:      78.36%
# Training F1:          86.65%  |  Test F1:          76.94%
# Training Time:      64.8648s  |  Test Time:      10.5204s
#
# EPOCH 24                         Total Runtime:  2917.37s
# Training Accuracy:    84.44%  |  Test Accuracy:    75.50%
# Training Precision:   80.87%  |  Test Precision:   70.56%
# Training Recall:      90.67%  |  Test Recall:      82.85%
# Training F1:          85.49%  |  Test F1:          76.21%
# Training Time:      64.9780s  |  Test Time:      10.5378s
#
# EPOCH 25                         Total Runtime:  3034.59s
# Training Accuracy:    86.59%  |  Test Accuracy:    76.75%
# Training Precision:   86.41%  |  Test Precision:   73.59%
# Training Recall:      87.21%  |  Test Recall:      79.42%
# Training F1:          86.80%  |  Test F1:          76.40%
# Training Time:      64.7616s  |  Test Time:      10.5490s
#
# EPOCH 26                         Total Runtime:  3151.47s
# Training Accuracy:    87.47%  |  Test Accuracy:    77.62%
# Training Precision:   87.35%  |  Test Precision:   74.75%
# Training Recall:      87.95%  |  Test Recall:      79.68%
# Training F1:          87.65%  |  Test F1:          77.14%
# Training Time:      64.6284s  |  Test Time:      10.5569s
#
# EPOCH 27                         Total Runtime:  3267.75s
# Training Accuracy:    87.75%  |  Test Accuracy:    80.50%
# Training Precision:   92.57%  |  Test Precision:   82.70%
# Training Recall:      82.39%  |  Test Recall:      74.41%
# Training F1:          87.18%  |  Test F1:          78.33%
# Training Time:      64.1907s  |  Test Time:      10.5374s
#
# EPOCH 28                         Total Runtime:  3384.16s
# Training Accuracy:    84.59%  |  Test Accuracy:    74.00%
# Training Precision:   81.20%  |  Test Precision:   68.47%
# Training Recall:      90.48%  |  Test Recall:      83.64%
# Training F1:          85.59%  |  Test F1:          75.30%
# Training Time:      64.3916s  |  Test Time:      10.5573s
#
# EPOCH 29                         Total Runtime:  3490.35s
# Training Accuracy:    84.81%  |  Test Accuracy:    74.50%
# Training Precision:   81.51%  |  Test Precision:   69.49%
# Training Recall:      90.48%  |  Test Recall:      82.32%
# Training F1:          85.76%  |  Test F1:          75.36%
# Training Time:      64.1030s  |  Test Time:      10.5614s
#
# EPOCH 30                         Total Runtime:  3543.00s
# Training Accuracy:    86.94%  |  Test Accuracy:    76.50%
# Training Precision:   85.80%  |  Test Precision:   73.24%
# Training Recall:      88.88%  |  Test Recall:      79.42%
# Training F1:          87.31%  |  Test F1:          76.20%
# Training Time:      30.2701s  |  Test Time:       4.4770s
#
# Clause #0 W: (-36 -32)
# Number of literals: 0
# Clause #1 W: (170 -101)
# Number of literals: 0
# Clause #2 W: (-67 -32) NOT x42 AND NOT x136 AND NOT x204 AND NOT x491
# Number of literals: 4
# Clause #3 W: (-52 5) NOT x103
# Number of literals: 1
# Clause #4 W: (24 -84) NOT x27 AND NOT x149 AND NOT x201 AND NOT x258
# Number of literals: 4
# Clause #5 W: (27 -65) NOT x0 AND NOT x273 AND NOT x323 AND NOT x466
# Number of literals: 4
# Clause #6 W: (-23 16) NOT x434
# Number of literals: 1
# Clause #7 W: (15 30) NOT x113
# Number of literals: 1
# Clause #8 W: (-107 146)
# Number of literals: 0
# Clause #9 W: (-9 59)
# Number of literals: 0
# [[347]
#  [187]
#  [495]
#  [ 36]
#  [229]
#  [403]
#  [281]
#  [ 45]
#  [  0]]
# {'right': 0, 'down_right': 1, 'down_left': 2, 'left': 3, 'right_X_chain': 4, 'up_left': 5, 'up_right': 6, 'down_right_X_chain': 7, 'left_X_chain': 8, 'down_right_O_chain': 9, 'down_left_X_chain': 10, 'up_left_X_chain': 11, 'right_O_chain': 12, 'up_left_O_chain': 13, 'down_left_O_chain': 14, 'left_O_chain': 15, 'up_right_X_chain': 16, 'up_right_O_chain': 17}
